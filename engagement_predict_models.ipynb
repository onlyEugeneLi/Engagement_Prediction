# %% [markdown]
# # Confusion matrix

# %% [markdown]
# ## CNN

# %%
import matplotlib.pyplot as plt
import numpy as np

# Visualize the confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center", fontsize=20,
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Define class labels
class_labels = [1, 2, 3]
test_cm = np.array([[0, 0, 6], [0, 0, 31], [0, 0, 151]])

# Plot confusion matrix
plot_confusion_matrix(test_cm, classes=class_labels, normalize=True, title='CNN Test Results Confusion Matrix')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## DL

# %%
import matplotlib.pyplot as plt
import numpy as np
# Visualize the confusion matrix with enhanced text visibility
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues,
                          text_size=12, text_color='black'):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=text_size)
    plt.yticks(tick_marks, classes, fontsize=text_size)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center", fontsize=text_size,
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=text_size, fontweight='bold')
    plt.xlabel('Predicted label', fontsize=text_size, fontweight='bold')
    plt.show()

class_labels = [1, 2, 3]
test_cm = np.array([[0, 0, 6], [0, 0, 31], [0, 0, 151]])

# Plot confusion matrix with enhanced text visibility
plot_confusion_matrix(test_cm, classes=class_labels, normalize=True, title='LSTM Normalised Confusion Matrix',
                      text_size=24, text_color='white')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## SVM

# %%
import matplotlib.pyplot as plt
import numpy as np
# Visualize the confusion matrix with enhanced text visibility
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues,
                          text_size=12, text_color='black'):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=text_size)
    plt.yticks(tick_marks, classes, fontsize=text_size)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center", fontsize=text_size,
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=text_size, fontweight='bold')
    plt.xlabel('Predicted label', fontsize=text_size, fontweight='bold')
    plt.show()

class_labels = [1, 2, 3]
test_cm = np.array([[2, 4, 0], [0, 13, 18], [1, 16, 134]])

# Plot confusion matrix with enhanced text visibility
plot_confusion_matrix(test_cm, classes=class_labels, normalize=True, title='SVM (Poly) Normalised Confusion Matrix',
                      text_size=24, text_color='white')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## kNN

# %%
import matplotlib.pyplot as plt
import numpy as np
# Visualize the confusion matrix with enhanced text visibility
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues,
                          text_size=12, text_color='black'):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=text_size)
    plt.yticks(tick_marks, classes, fontsize=text_size)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center", fontsize=text_size,
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=text_size, fontweight='bold')
    plt.xlabel('Predicted label', fontsize=text_size, fontweight='bold')
    plt.show()

class_labels = [1, 2, 3]
test_cm = np.array([[1, 1, 4], [0, 2, 29], [0, 2, 149]])

# Plot confusion matrix with enhanced text visibility
plot_confusion_matrix(test_cm, classes=class_labels, normalize=True, title='kNN (k=12) Normalised Confusion Matrix',
                      text_size=24, text_color='white')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## RF

# %%
import matplotlib.pyplot as plt
import numpy as np
# Visualize the confusion matrix with enhanced text visibility
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues,
                          text_size=12, text_color='black'):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=text_size)
    plt.yticks(tick_marks, classes, fontsize=text_size)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center", fontsize=text_size,
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=text_size, fontweight='bold')
    plt.xlabel('Predicted label', fontsize=text_size, fontweight='bold')
    plt.show()

class_labels = [1, 2, 3]
test_cm = np.array([[1, 1, 4], [0, 5, 26], [1, 1, 149]])

# Plot confusion matrix with enhanced text visibility
plot_confusion_matrix(test_cm, classes=class_labels, normalize=True, title='RF Normalised Confusion Matrix',
                      text_size=24, text_color='white')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## LR

# %%
import matplotlib.pyplot as plt
import numpy as np
# Visualize the confusion matrix with enhanced text visibility
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues,
                          text_size=12, text_color='black'):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=text_size)
    plt.yticks(tick_marks, classes, fontsize=text_size)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center", fontsize=text_size,
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=text_size, fontweight='bold')
    plt.xlabel('Predicted label', fontsize=text_size, fontweight='bold')
    plt.show()

class_labels = [1, 2, 3]
test_cm = np.array([[0, 4, 2], [0, 2, 29], [0, 1, 150]])

# Plot confusion matrix with enhanced text visibility
plot_confusion_matrix(test_cm, classes=class_labels, normalize=True, title='LR Normalised Confusion Matrix',
                      text_size=24, text_color='white')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## NB

# %%
import matplotlib.pyplot as plt
import numpy as np
# Visualize the confusion matrix with enhanced text visibility
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues,
                          text_size=12, text_color='black'):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=text_size)
    plt.yticks(tick_marks, classes, fontsize=text_size)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center", fontsize=text_size,
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=text_size, fontweight='bold')
    plt.xlabel('Predicted label', fontsize=text_size, fontweight='bold')
    plt.show()

class_labels = [1, 2, 3]
test_cm = np.array([[1, 4, 1], [0, 15, 16], [2, 27, 122]])

# Plot confusion matrix with enhanced text visibility
plot_confusion_matrix(test_cm, classes=class_labels, normalize=True, title='NB Normalised Confusion Matrix',
                      text_size=24, text_color='white')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## DT

# %%
import matplotlib.pyplot as plt
import numpy as np
# Visualize the confusion matrix with enhanced text visibility
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues,
                          text_size=12, text_color='black'):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14, fontweight='bold')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=text_size)
    plt.yticks(tick_marks, classes, fontsize=text_size)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center", fontsize=text_size,
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=text_size, fontweight='bold')
    plt.xlabel('Predicted label', fontsize=text_size, fontweight='bold')
    plt.show()

class_labels = [1, 2, 3]
test_cm = np.array([[1, 1, 4], [0, 10, 21], [1, 16, 134]])

# Plot confusion matrix with enhanced text visibility
plot_confusion_matrix(test_cm, classes=class_labels, normalize=True, title='DT Normalised Confusion Matrix',
                      text_size=24, text_color='white')
# Out:
# Normalized confusion matrix

# %% [markdown]
# # F1-scores

# %%
import matplotlib.pyplot as plt

# Example F1-scores for three classes from seven models
class_labels = ["1", "2", "3"]
model_names = ["SVM", "kNN", "RF", "DT", "NB", "LR", "DL"]
f1_scores = [
    [0.44, 0.41, 0.88],
    [0.29, 0.11, 0.89],
    [0.25, 0.26, 0.90],
    [0.25, 0.34, 0.86],
    [0.22, 0.39, 0.84],
    [0.00, 0.11, 0.90],
    [0.00, 0.00, 0.90]
]

# Create a bar plot
fig, ax = plt.subplots(figsize=(10, 6))

for i, class_label in enumerate(class_labels):
    ax.bar([x + i * 0.15 for x in range(len(model_names))], [score[i] for score in f1_scores], width=0.15, label=class_label)

ax.set_xlabel('Models')
ax.set_ylabel('F1-Score')
ax.set_title('F1-Scores by Class and Model')
ax.set_xticks([x + 0.3 for x in range(len(model_names))])
ax.set_xticklabels(model_names, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## With number text

# %%
import matplotlib.pyplot as plt

# Example F1-scores for three classes from seven models
class_labels = ["1", "2", "3"]
model_names = ["SVM", "kNN (k=12)", "Random Forest", "Decision Tree", "Naive Bayes", "Logistic regression", "DL"]
f1_scores = [
    [0.44, 0.41, 0.88],
    [0.29, 0.11, 0.89],
    [0.25, 0.26, 0.90],
    [0.25, 0.34, 0.86],
    [0.22, 0.39, 0.84],
    [0.00, 0.11, 0.90],
    [0.00, 0.00, 0.90]
]

# Create a bar plot with text labels
fig, ax = plt.subplots(figsize=(10, 6))

for i, class_label in enumerate(class_labels):
    bars = ax.bar([x + i * 0.15 for x in range(len(model_names))], [score[i] for score in f1_scores], width=0.15, label=class_label)
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

ax.set_xlabel('Models')
ax.set_ylabel('F1-Score')
ax.set_title('F1-Scores by Class and Model')
ax.set_xticks([x + 0.3 for x in range(len(model_names))])
ax.set_xticklabels(model_names, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bigger font

# %%
import matplotlib.pyplot as plt

# Example F1-scores for three classes from seven models
class_labels = ["1", "2", "3"]
model_names = ["SVM", "kNN", "RF", "DT", "NB", "LR", "DL"]
f1_scores = [
    [0.44, 0.41, 0.88],
    [0.29, 0.11, 0.89],
    [0.25, 0.26, 0.90],
    [0.25, 0.34, 0.86],
    [0.22, 0.39, 0.84],
    [0.00, 0.11, 0.90],
    [0.00, 0.00, 0.90]
]

# Create a bar plot with larger text
fig, ax = plt.subplots(figsize=(12, 8))

for i, class_label in enumerate(class_labels):
    ax.bar([x + i * 0.15 for x in range(len(model_names))], [score[i] for score in f1_scores], width=0.15, label=class_label)

ax.set_xlabel('Models', fontsize=18)
ax.set_ylabel('F1-Score', fontsize=18)
ax.set_title('F1-Scores by Class and Model', fontsize=18)
ax.set_xticks([x + 0.3 for x in range(len(model_names))])
ax.set_xticklabels(model_names, rotation=45, ha='right', fontsize=18)
ax.legend(fontsize=18)

# Increase the size of tick labels
ax.tick_params(axis='both', which='major', labelsize=18)

plt.tight_layout()
plt.show()

# %% [markdown]
# # SVM

# %% [markdown]
# ## Simple version

# %% [markdown]
# ### Emotion + Human motion + Head pose

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import joblib
# Specify the number of folds for cross-validation
num_folds = 5

# Create a KFold cross-validation object
kf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Read data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")
dataset.loc[dataset['label'] == 0] = 1
dataset.to_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")

# %%
# Read data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")
X = dataset.drop(columns=['data_id', 'label'])
# print(x.head(5))
# print('\nStandardising...')
# scaler = StandardScaler()
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(X)
# print(x.head(5))
y = dataset['label']
# print(y.head(5))

# Assuming you have y (labels)
class_labels, class_counts = np.unique(y, return_counts=True)

for label, count in zip(class_labels, class_counts):
    print(f"Class {label}: {count} instances")
# Out:
# Class 1: 14 instances
# Class 2: 107 instances
# Class 3: 503 instances

# %%
# Assuming you have X (features) and y (labels)
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=42)

# Instantiate SVM classifier (C-SVC with linear kernel)
clf = svm.SVC(kernel='poly', degree=6, class_weight='balanced')

# Train the model
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", report)

cm = confusion_matrix(y_test, y_pred)

cmdict = {'svm': cm}

print(type(report))

print(type(cm))
print(cmdict['svm'])
# Out:
# Accuracy: 0.7925531914893617
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.67      0.33      0.44         6
#            2       0.39      0.42      0.41        31
#            3       0.88      0.89      0.88       151
#
#     accuracy                           0.79       188
#    macro avg       0.65      0.55      0.58       188
# weighted avg       0.79      0.79      0.79       188
#
# <class 'str'>
# <class 'numpy.ndarray'>
# [[  2   4   0]
#  [  0  13  18]
#  [  1  16 134]]

# %%
# Save the trained model to a file
model_filename = "/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/svm_poly6_she.pkl"
joblib.dump(clf, model_filename)
# Out:
# ["/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/svm_poly6_she.pkl"]

# %% [markdown]
# ## Cross validation

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn import svm
from sklearn.model_selection import StratifiedKFold

# %%
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")
X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(X)
y = dataset['label']
# Assuming you have X (features) and y (labels)
# Instantiate the SVM classifier
clf = svm.SVC(kernel='rbf', class_weight='balanced')

# # Specify the number of folds for cross-validation
# num_folds = 5

# # Create a KFold cross-validation object
# kf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Perform cross-validation and calculate accuracy scores
accuracy_scores = cross_val_score(clf, x_scaled, y, cv=kf, scoring='accuracy')

# Print accuracy scores for each fold
for fold, accuracy in enumerate(accuracy_scores, start=1):
    print(f"Fold {fold} Accuracy: {accuracy:.2f}")

# Calculate and print the mean and standard deviation of accuracy scores
mean_accuracy = accuracy_scores.mean()
std_accuracy = accuracy_scores.std()
print(f"Mean Accuracy: {mean_accuracy:.2f}")
print(f"Standard Deviation of Accuracy: {std_accuracy:.2f}")
# Out:
# Fold 1 Accuracy: 0.74
# Fold 2 Accuracy: 0.76
# Fold 3 Accuracy: 0.74
# Fold 4 Accuracy: 0.70
# Fold 5 Accuracy: 0.73
# Mean Accuracy: 0.73
# Standard Deviation of Accuracy: 0.02

# %%
# Save the trained model to a file
model_filename = "/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/svm_poly6_cv_she.pkl"
joblib.dump(clf, model_filename)

# %% [markdown]
# ## Balanced class distribution

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Assuming you have X (features) and y (labels)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate SVM classifier with class weights
clf = svm.SVC(kernel='poly', degree=6, class_weight='balanced')

# Train the model
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# Evaluate the model
report = classification_report(y_test, y_pred)

print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.50      0.33      0.40         6
#            2       0.50      0.35      0.42        31
#            3       0.86      0.75      0.80       151
#
#     accuracy                           0.68       188
#    macro avg       0.46      0.36      0.40       188
# weighted avg       0.79      0.68      0.73       188
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # kNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.model_selection import StratifiedKFold

from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Specify the number of folds for cross-validation
num_folds = 5

# Create a KFold cross-validation object
kf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %% [markdown]
# ## Finding optimal number of neighbours

# %%
# Read data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")
X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(X)
y = dataset['label']
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=42)

param_grid = {'n_neighbors': range(3, 15)}  # Adjust the range as needed
knn_model = KNeighborsClassifier()
grid_search = GridSearchCV(knn_model, param_grid, cv=kf, scoring='accuracy')
grid_search.fit(X_train, y_train)

best_k = grid_search.best_params_['n_neighbors']
best_accuracy = grid_search.best_score_

# %%
print(f"The optimal k is: {best_k}")
print(f"The average accuracy is: {best_accuracy:.2f}")
# Out:
# The optimal k is: 12
# The average accuracy is: 0.82

# %% [markdown]
# ## Cross validation: SHE

# %%
# Read data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")
X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(X)
y = dataset['label']
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=42)

knn_model = KNeighborsClassifier(n_neighbors=best_k)

# Use cross_val_predict to get predicted labels for each fold

predicted_labels = cross_val_predict(knn_model, X_train, y_train, cv=kf)

# Calculate the overall confusion matrix
# cm = confusion_matrix(y, predicted_labels)
# print("Confusion Matrix:\n", cm)

# Calculate the classification report for each fold
# report = classification_report(y, predicted_labels)

# print("Classification Report:\n", report)

# Fit the model on the entire training data
knn_model.fit(X_train, y_train)

# Evaluate the model on the test set
test_predicted_labels = knn_model.predict(X_test)
test_cm = confusion_matrix(y_test, test_predicted_labels)
test_report = classification_report(y_test, test_predicted_labels)
print("Test Set Confusion Matrix:\n", test_cm)
print("Test Set Classification Report:\n", test_report)
# Out:
# Test Set Confusion Matrix:
#  [[  1   1   4]
#  [  0   2  29]
#  [  0   2 149]]
# Test Set Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.17      0.29         6
#            2       0.40      0.06      0.11        31
#            3       0.82      0.99      0.89       151
#
#     accuracy                           0.81       188
#    macro avg       0.74      0.41      0.43       188
# weighted avg       0.76      0.81      0.75       188

# %%
report = classification_report(y_train, predicted_labels)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         8
#            2       0.53      0.12      0.19        76
#            3       0.83      0.99      0.90       352
#
#     accuracy                           0.82       436
#    macro avg       0.45      0.37      0.36       436
# weighted avg       0.76      0.82      0.76       436
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Save the trained model to a file
model_filename = "/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/knn_k12_cv_she.pkl"
joblib.dump(knn_model, model_filename)
# Out:
# ["/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/knn_k12_cv_she.pkl"]

# %% [markdown]
# # Random forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report

# Load the dataset
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")

# Prepare the data
X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(X)
y = dataset['label']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=42)

# Create the Random Forest model
rf_model = RandomForestClassifier(random_state=42)

# Perform cross-validation to get predicted labels for each fold
predicted_labels = cross_val_predict(rf_model, X_train, y_train, cv=kf)

# Calculate the confusion matrix
cm = confusion_matrix(y_train, predicted_labels)
print("Cross Validation Confusion Matrix:\n", cm)

# Calculate the classification report
report = classification_report(y_train, predicted_labels)
print("Cross Validation Classification Report:\n", report)

# Fit the model on the entire training data
rf_model.fit(X_train, y_train)

# Evaluate the model on the test set
test_predicted_labels = rf_model.predict(X_test)
test_cm = confusion_matrix(y_test, test_predicted_labels)
test_report = classification_report(y_test, test_predicted_labels)
print("Test Set Confusion Matrix:\n", test_cm)
print("Test Set Classification Report:\n", test_report)
# Out:
# Cross Validation Confusion Matrix:
#  [[  4   1   3]
#  [  0  11  65]
#  [  0   4 348]]
# Cross Validation Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.50      0.67         8
#            2       0.69      0.14      0.24        76
#            3       0.84      0.99      0.91       352
#
#     accuracy                           0.83       436
#    macro avg       0.84      0.54      0.60       436
# weighted avg       0.81      0.83      0.79       436
#
# Test Set Confusion Matrix:
#  [[  1   1   4]
#  [  0   5  26]
#  [  1   1 149]]
# Test Set Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.50      0.17      0.25         6
#            2       0.71      0.16      0.26        31
#            3       0.83      0.99      0.90       151
#
#     accuracy                           0.82       188
#    macro avg       0.68      0.44      0.47       188
# ...

# %%
# Save the trained model to a file
model_filename = "/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/rf_cv_she.pkl"
joblib.dump(rf_model, model_filename)
# Out:
# ["/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/rf_cv_she.pkl"]

# %% [markdown]
# # Logistic regression

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression

# %%
# Load the dataset
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")

# Prepare the data
X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(X)
y = dataset['label']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=42)

# %%
lr_model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)

# Perform cross-validation to get predicted labels for each fold
predicted_labels = cross_val_predict(lr_model, X_train, y_train, cv=kf)

# # Calculate the confusion matrix
# cm = confusion_matrix(y_train, predicted_labels)
# print("Confusion Matrix:\n", cm)

# Calculate the classification report
report = classification_report(y_train, predicted_labels)
print("Classification Report:\n", report)

# Fit the model on the entire training data
lr_model.fit(X_train, y_train)

# Evaluate the model on the test set
test_predicted_labels = lr_model.predict(X_test)
test_cm = confusion_matrix(y_test, test_predicted_labels)
test_report = classification_report(y_test, test_predicted_labels)
print("Test Set Confusion Matrix:\n", test_cm)
print("Test Set Classification Report:\n", test_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.12      0.22         8
#            2       0.28      0.07      0.11        76
#            3       0.82      0.98      0.89       352
#
#     accuracy                           0.80       436
#    macro avg       0.70      0.39      0.41       436
# weighted avg       0.73      0.80      0.74       436
#
# Test Set Confusion Matrix:
#  [[  0   4   2]
#  [  0   2  29]
#  [  0   1 150]]
# Test Set Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         6
#            2       0.29      0.06      0.11        31
#            3       0.83      0.99      0.90       151
#
#     accuracy                           0.81       188
#    macro avg       0.37      0.35      0.34       188
# weighted avg       0.71      0.81      0.74       188
# ...

# %%
# Save the trained model to a file
model_filename = "/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/lr_cv_she.pkl"
joblib.dump(lr_model, model_filename)
# Out:
# ["/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/lr_cv_she.pkl"]

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# ## SHE

# %%
import pandas as pd
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report

# Load and preprocess the data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")

X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
y = dataset['label']

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Create the Naive Bayes model
nb_model = GaussianNB()

# Perform cross-validation to get predicted labels for each fold
predicted_labels_train = cross_val_predict(nb_model, X_train, y_train, cv=kf)

# Calculate the confusion matrix and classification report for training data
train_cm = confusion_matrix(y_train, predicted_labels_train)
train_report = classification_report(y_train, predicted_labels_train)

# Fit the model on the entire training data
nb_model.fit(X_train, y_train)

# Predict on the test data
predicted_labels_test = nb_model.predict(X_test)

# Calculate the confusion matrix and classification report for test data
test_cm = confusion_matrix(y_test, predicted_labels_test)
test_report = classification_report(y_test, predicted_labels_test)

# Print the results
print("Training Set Confusion Matrix:\n", train_cm)
print("Training Set Classification Report:\n", train_report)
print("Test Set Confusion Matrix:\n", test_cm)
print("Test Set Classification Report:\n", test_report)
# Out:
# Training Set Confusion Matrix:
#  [[  5   3   0]
#  [  3  33  40]
#  [  5  65 282]]
# Training Set Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.38      0.62      0.48         8
#            2       0.33      0.43      0.37        76
#            3       0.88      0.80      0.84       352
#
#     accuracy                           0.73       436
#    macro avg       0.53      0.62      0.56       436
# weighted avg       0.77      0.73      0.75       436
#
# Test Set Confusion Matrix:
#  [[  1   4   1]
#  [  0  15  16]
#  [  2  27 122]]
# Test Set Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.33      0.17      0.22         6
#            2       0.33      0.48      0.39        31
#            3       0.88      0.81      0.84       151
#
#     accuracy                           0.73       188
#    macro avg       0.51      0.49      0.48       188
# ...

# %%
# Save the trained model to a file
model_filename = "/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/nb_cv_she.pkl"
joblib.dump(nb_model, model_filename)
# Out:
# ["/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/nb_cv_she.pkl"]

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## SHE

# %%
import pandas as pd
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report

# Load and preprocess the data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")

X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
y = dataset['label']

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Create the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)

# Perform cross-validation to get predicted labels for each fold
predicted_labels_train = cross_val_predict(dt_model, X_train, y_train, cv=kf)

# Calculate the confusion matrix and classification report for training data
train_cm = confusion_matrix(y_train, predicted_labels_train)
train_report = classification_report(y_train, predicted_labels_train)

# Fit the model on the entire training data
dt_model.fit(X_train, y_train)

# Predict on the test data
predicted_labels_test = dt_model.predict(X_test)

# Calculate the confusion matrix and classification report for test data
test_cm = confusion_matrix(y_test, predicted_labels_test)
test_report = classification_report(y_test, predicted_labels_test)

# Print the results
print("Training Set Confusion Matrix:\n", train_cm)
print("Training Set Classification Report:\n", train_report)
print("Test Set Confusion Matrix:\n", test_cm)
print("Test Set Classification Report:\n", test_report)

# Save the model using joblib
model_filename = "/content/drive/MyDrive/King's College London/Individual Project/Data/trained_models/dt_cv_she.pkl"
joblib.dump(dt_model, model_filename)
# Out:
# Training Set Confusion Matrix:
#  [[  5   2   1]
#  [  7  22  47]
#  [  2  58 292]]
# Training Set Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.36      0.62      0.45         8
#            2       0.27      0.29      0.28        76
#            3       0.86      0.83      0.84       352
#
#     accuracy                           0.73       436
#    macro avg       0.49      0.58      0.53       436
# weighted avg       0.75      0.73      0.74       436
#
# Test Set Confusion Matrix:
#  [[  1   1   4]
#  [  0  10  21]
#  [  1  16 134]]
# Test Set Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.50      0.17      0.25         6
#            2       0.37      0.32      0.34        31
#            3       0.84      0.89      0.86       151
#
#     accuracy                           0.77       188
#    macro avg       0.57      0.46      0.49       188
# ...

# %% [markdown]
# # CNN

# %% [markdown]
# ## Simple

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix

# Load and preprocess the data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")

X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

y = dataset['label']
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# class_weights = {0: 1.0, 1: 1.0, 2: 1.0}

# Create the CNN model
model = Sequential([
    Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
    MaxPooling1D(pool_size=2),
    Conv1D(64, kernel_size=3, activation='relu'),
    GlobalMaxPooling1D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Reshape the data for 1D convolution
X_train_reshaped = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Train the model
model.fit(X_train_reshaped, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test_reshaped, y_test)
print("Test accuracy:", test_acc)

# Predict on the test data
test_predictions = model.predict(X_test_reshaped)
test_predicted_labels = np.argmax(test_predictions, axis=-1)

# Calculate the classification report and confusion matrix
test_cm = confusion_matrix(y_test, test_predicted_labels)

# Print the results
print("Test Set Confusion Matrix:\n", test_cm)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 2s 47ms/step - loss: 1.0031 - accuracy: 0.7500 - val_loss: 0.8671 - val_accuracy: 0.8636
# Epoch 2/10
# 11/11 [==============================] - 0s 24ms/step - loss: 0.7854 - accuracy: 0.7931 - val_loss: 0.5750 - val_accuracy: 0.8636
# Epoch 3/10
# 11/11 [==============================] - 0s 16ms/step - loss: 0.6451 - accuracy: 0.7931 - val_loss: 0.4705 - val_accuracy: 0.8636
# Epoch 4/10
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6309 - accuracy: 0.7931 - val_loss: 0.4743 - val_accuracy: 0.8636
# Epoch 5/10
# 11/11 [==============================] - 0s 22ms/step - loss: 0.5806 - accuracy: 0.7931 - val_loss: 0.4758 - val_accuracy: 0.8636
# Epoch 6/10
# 11/11 [==============================] - 0s 13ms/step - loss: 0.5995 - accuracy: 0.7931 - val_loss: 0.4644 - val_accuracy: 0.8636
# Epoch 7/10
# ...

# %% [markdown]
# # RNN

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

# Load and preprocess the data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")

X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

y = dataset['label']
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# Create the RNN model
model = Sequential([
    Embedding(input_dim=X_train.shape[1], output_dim=128, input_length=X_train.shape[1]),
    SimpleRNN(64),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Predict on the test data
test_predictions = model.predict(X_test)
test_predicted_labels = np.argmax(test_predictions, axis=-1)

# Calculate the confusion matrix
test_cm = confusion_matrix(y_test, test_predicted_labels)

# Print the confusion matrix
print("Test Set Confusion Matrix:\n", test_cm)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 5s 89ms/step - loss: 0.8543 - accuracy: 0.7040 - val_loss: 0.4778 - val_accuracy: 0.8636
# Epoch 2/10
# 11/11 [==============================] - 0s 33ms/step - loss: 0.6579 - accuracy: 0.7931 - val_loss: 0.7438 - val_accuracy: 0.8636
# Epoch 3/10
# 11/11 [==============================] - 0s 35ms/step - loss: 0.6374 - accuracy: 0.7931 - val_loss: 0.4503 - val_accuracy: 0.8636
# Epoch 4/10
# 11/11 [==============================] - 0s 31ms/step - loss: 0.6023 - accuracy: 0.7931 - val_loss: 0.4843 - val_accuracy: 0.8636
# Epoch 5/10
# 11/11 [==============================] - 0s 33ms/step - loss: 0.5909 - accuracy: 0.7931 - val_loss: 0.4439 - val_accuracy: 0.8636
# Epoch 6/10
# 11/11 [==============================] - 0s 32ms/step - loss: 0.5908 - accuracy: 0.7931 - val_loss: 0.4510 - val_accuracy: 0.8636
# Epoch 7/10
# ...

# %% [markdown]
# # LSTM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, accuracy_score

# Load and preprocess the data
dataset = pd.read_csv("/content/drive/MyDrive/King's College London/Individual Project/Data/lisi-hri-visual-no-nan.csv")

X = dataset.drop(columns=['data_id', 'label'])
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

y = dataset['label']
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# Create the LSTM model
model = Sequential([
    Embedding(input_dim=X_train.shape[1], output_dim=128, input_length=X_train.shape[1]),
    LSTM(64),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", test_accuracy)

# Predict on the test data
test_predictions = model.predict(X_test)
test_predicted_labels = np.argmax(test_predictions, axis=-1)

# Calculate the confusion matrix
test_cm = confusion_matrix(y_test, test_predicted_labels)

# Print the confusion matrix
print("Test Set Confusion Matrix:\n", test_cm)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 7s 122ms/step - loss: 0.9255 - accuracy: 0.7672 - val_loss: 0.5047 - val_accuracy: 0.8636
# Epoch 2/10
# 11/11 [==============================] - 1s 67ms/step - loss: 0.6552 - accuracy: 0.7931 - val_loss: 0.5100 - val_accuracy: 0.8636
# Epoch 3/10
# 11/11 [==============================] - 1s 67ms/step - loss: 0.5945 - accuracy: 0.7931 - val_loss: 0.4382 - val_accuracy: 0.8636
# Epoch 4/10
# 11/11 [==============================] - 1s 66ms/step - loss: 0.6171 - accuracy: 0.7960 - val_loss: 0.4640 - val_accuracy: 0.8636
# Epoch 5/10
# 11/11 [==============================] - 1s 64ms/step - loss: 0.6104 - accuracy: 0.7960 - val_loss: 0.4636 - val_accuracy: 0.8636
# Epoch 6/10
# 11/11 [==============================] - 1s 69ms/step - loss: 0.5804 - accuracy: 0.7989 - val_loss: 0.4481 - val_accuracy: 0.8636
# Epoch 7/10
# ...
